# %% [markdown]
# ### Importing the libraries

# %%
! pip install fredapi
# Out:
# Requirement already satisfied: fredapi in c:\users\ibrah\appdata\local\programs\python\python311\lib\site-packages (0.5.0)
# Requirement already satisfied: pandas in c:\users\ibrah\appdata\local\programs\python\python311\lib\site-packages (from fredapi) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ibrah\appdata\local\programs\python\python311\lib\site-packages (from pandas->fredapi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ibrah\appdata\local\programs\python\python311\lib\site-packages (from pandas->fredapi) (2022.6)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ibrah\appdata\local\programs\python\python311\lib\site-packages (from pandas->fredapi) (1.23.4)
# Requirement already satisfied: six>=1.5 in c:\users\ibrah\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.1->pandas->fredapi) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import plotly.express as px

plt.style.use('fivethirtyeight')
# pd.set_option('max_columns', 500)
# pd.set_option('max_rows', 500)
color_pal = plt.rcParams['axes.prop_cycle'].by_key()['color']

from fredapi import Fred

fred_key = 'ab1a0a173beb386efc89fe86b4df1a78'

# %% [markdown]
# Create Fred object

# %%
fred = Fred(api_key=fred_key)

# %% [markdown]
# Search for economic data

# %%
sp_search = fred.search('S&P' , order_by = 'popularity')

# %%
sp_search

# %% [markdown]
# Pull raw data & plot

# %%
sp500 = fred.get_series(series_id='SP500')

# %%
sp500.plot(figsize=(10,5), title='SP500')
# Out:
# <AxesSubplot: title={'center': 'SP500'}>

# %% [markdown]
# Pull and join multiple Data Series

# %%
unemp_search = fred.search('Unemployment')

# %%
unrate = fred.get_series('UNRATE')
